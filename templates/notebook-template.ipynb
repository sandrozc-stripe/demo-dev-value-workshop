# %% [markdown]
# # Lab XX: [Topic] - [Notebook Title]
#
# **Lab**: XX-lab-name
# **Duration**: ~XX minutes
# **Prerequisites**: [List prerequisites]
#
# ## Learning Objectives
#
# By the end of this notebook, you will:
# - [Objective 1]
# - [Objective 2]
# - [Objective 3]
#
# ---

# %% [markdown]
# ## Setup
#
# Let's verify our environment is ready.
#
# <!-- PRESENTER: Verify attendees have prerequisites installed -->

# %%
# Environment setup
import os
from dotenv import load_dotenv
import stripe

load_dotenv()
stripe.api_key = os.environ.get('STRIPE_API_KEY')

# Verify connection
try:
    account = stripe.Account.retrieve()
    print(f"Connected to Stripe account: {account.id}")
    print(f"Mode: {'Test' if 'test' in stripe.api_key else 'LIVE - BE CAREFUL!'}")
except stripe.error.AuthenticationError:
    print("ERROR: Invalid API key. Check your .env file.")

# %% [markdown]
# ## Section 1: [Topic]
#
# [Explanation of the concept - what it is, why it matters]
#
# ### Key Points
#
# 1. **Point 1**: Description
# 2. **Point 2**: Description
# 3. **Point 3**: Description

# %%
# Code example for Section 1
# Clear comments explaining what the code does

# Expected output: [describe what should happen]

# %% [markdown]
# ### Checkpoint
#
# At this point, you should see:
# - [Expected state 1]
# - [Expected state 2]
#
# **Dashboard**: Navigate to [relevant page](https://dashboard.stripe.com/test/...) to verify.

# %% [markdown]
# ## Section 2: [Topic]
#
# [Explanation continues...]
#
# <!-- PRESENTER: Pause here for questions -->

# %%
# Code example for Section 2

# %% [markdown]
# ## Cleanup (Optional)
#
# Run the cell below to clean up resources created in this lab.

# %%
# Optional cleanup
# Uncomment to delete created resources
# stripe.Resource.delete(resource_id)

# %% [markdown]
# ## Summary
#
# In this notebook, you learned:
#
# - **Key takeaway 1**: Description
# - **Key takeaway 2**: Description
# - **Key takeaway 3**: Description
#
# ## Next Steps
#
# Continue to `02_next_notebook.ipynb` to learn about [next topic]!
